# %% [markdown]
# ### 1. import needed libraries

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os

# %% [markdown]
# ### 2. call on url and see layout

# %%
url = "https://en.wikipedia.org/wiki/World_Happiness_Report"
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %% [markdown]
# ### 3. select needed table

# %%
table = soup.find_all('table',{'class':'wikitable sortable'})[0]

# %% [markdown]
# ### 4. check on rows, layout, data and select needed info

# %%
rows = table.find_all('tr')
#rows = [row.text.strip().split("\n") for row in rows]
rows = [row.text.replace("\n\n", ",").replace("\n", ",").replace("\xa0", "").strip(",").split(",") for row in rows]
rows [:2]
# Out:
# [['Overall rank',
#   'Country or region',
#   'Score',
#   'GDP per capita',
#   'Social support',
#   'Healthy life expectancy',
#   'Freedom to make life choices',
#   'Generosity',
#   'Perceptions of corruption'],
#  ['1',
#   'Finland',
#   '7.632',
#   '1.305',
#   '1.592',
#   '0.874',
#   '0.681',
#   '0.192',
#   '0.393']]

# %% [markdown]
# ### 5. create db

# %%
colnames = rows[0]
data = rows[1:]

happiness_2018_extended = pd.DataFrame(data, columns=colnames)
happiness_2018_extended.head(20)
# Out:
#    Overall rank     Country or region  Score GDP per capita Social support  \
# 0             1               Finland  7.632          1.305          1.592
# 1             2                Norway  7.594          1.456          1.582
# 2             3               Denmark  7.555          1.351          1.590
# 3             4               Iceland  7.495          1.343          1.644
# 4             5           Switzerland  7.487          1.420          1.549
# 5             6           Netherlands  7.441          1.361          1.488
# 6             7                Canada  7.328          1.330          1.532
# 7             8           New Zealand  7.324          1.268          1.601
# 8             9                Sweden  7.314          1.355          1.501
# 9            10             Australia  7.272          1.340          1.573
# 10           11                Israel  7.190          1.244          1.433
# 11           12               Austria  7.139          1.341          1.504
# 12           13            Costa Rica  7.072          1.010          1.459
# 13           14               Ireland  6.977          1.448          1.583
# 14           15               Germany  6.965          1.340          1.474
# 15           16               Belgium  6.927          1.324          1.483
# 16           17            Luxembourg  6.910          1.576          1.520
# 17           18         United States  6.886          1.398          1.471
# 18           19        United Kingdom  6.814          1.301          1.559
# 19           20  United Arab Emirates  6.774          2.096          0.776
#
#    Healthy life expectancy Freedom to make life choices Generosity  \
# 0                    0.874                        0.681      0.192
# 1                    0.861                        0.686      0.286
# 2                    0.868                        0.683      0.284
# 3                    0.914                        0.677      0.353
# 4                    0.927                        0.660      0.256
# 5                    0.878                        0.638      0.333
# 6                    0.896                        0.653      0.321
# 7                    0.876                        0.669      0.365
# 8                    0.913                        0.659      0.285
# 9                    0.910                        0.647      0.361
# 10                   0.888                        0.464      0.262
# 11                   0.891                        0.617      0.242
# 12                   0.817                        0.632      0.143
# 13                   0.876                        0.614      0.307
# 14                   0.861                        0.586      0.273
# 15                   0.894                        0.583      0.188
# 16                   0.896                        0.632      0.196
# 17                   0.819                        0.547      0.291
# 18                   0.883                        0.533      0.354
# 19                   0.670                        0.284      0.186
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357
# 5                      0.295
# 6                      0.291
# 7                      0.389
# 8                      0.383
# 9                      0.302
# 10                     0.082
# 11                     0.224
# 12                     0.101
# 13                     0.306
# 14                     0.280
# 15                     0.240
# 16                     0.321
# 17                     0.133
# 18                     0.272
# 19                       N/A

# %% [markdown]
# ### 6. basic data cleaning + data selectin

# %%
os.getcwd()
os.chdir("../Data")

# %% [markdown]
# #####  save oroginal to csv (to avoid data loss)

# %%
happiness_2018_extended.to_csv("../Data/backup_raw_data/happiness_2018_extended.csv")

# %% [markdown]
# ##### select countries for research

# %%
#countries we will use:
# spain, netherlands, france, denmak, sweden, italy, poland, belgium, greece, austria

# %%
country_list = ["Spain", "Netherlands", "France", "Greece", "Austria", "Denmark", "Belgium", "Italy", "Poland", "Sweden"]

# %%
happiness_2018 = pd.read_csv("../Data/backup_raw_data/happiness_2018_extended.csv")
happiness_2018 = happiness_2018[(happiness_2018["Country or region"].isin(country_list))]

# %%
happiness_2018 = happiness_2018.rename(columns={"Country or region":"Country",
                                                "Happiness score":"Score",
                                                "Generosity":"Generosity importance", 
                                                "GDP per capita":"GDP", 
                                                "Freedom to make life choices":"Freedom"})
# no need to have the rank and the unnamed as we will not analyse by rank but by score:
happiness_2018 = happiness_2018.drop(["Overall rank"], axis=1)
happiness_2018 = happiness_2018.drop(["Unnamed: 0"], axis=1)

# %%
happiness_2018
# Out:
#         Country  Score    GDP  Social support  Healthy life expectancy  \
# 2       Denmark  7.555  1.351           1.590                    0.868
# 5   Netherlands  7.441  1.361           1.488                    0.878
# 8        Sweden  7.314  1.355           1.501                    0.913
# 11      Austria  7.139  1.341           1.504                    0.891
# 15      Belgium  6.927  1.324           1.483                    0.894
# 22       France  6.489  1.293           1.466                    0.908
# 35        Spain  6.310  1.251           1.538                    0.965
# 41       Poland  6.123  1.176           1.448                    0.781
# 46        Italy  6.000  1.264           1.501                    0.946
# 78       Greece  5.358  1.154           1.202                    0.879
#
#     Freedom  Generosity importance  Perceptions of corruption
# 2     0.683                  0.284                      0.408
# 5     0.638                  0.333                      0.295
# 8     0.659                  0.285                      0.383
# 11    0.617                  0.242                      0.224
# 15    0.583                  0.188                      0.240
# 22    0.520                  0.098                      0.176
# 35    0.449                  0.142                      0.074
# 41    0.546                  0.108                      0.064
# 46    0.281                  0.137                      0.028
# 78    0.131                  0.000                      0.044

# %% [markdown]
# ##### save new to csv to be able to work on it

# %%
happiness_2018.to_csv("../Data/happiness_2018.csv")
